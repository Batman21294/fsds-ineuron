# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='area',alpha=0.4)
# Out:
# <Axes: >

# %%
df.plot(kind='area',alpha=0.4,stacked=False)
# Out:
# <Axes: >

# %%
df.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y='sepal_width',c='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y='sepal_width',c='sepal_width',s=1000)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y='sepal_width',c='sepal_width',s=df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1,6,30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,6,30)
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
def sin_func(x,y):
    return np.sin(np.sqrt(x**2+y**2))

# %%
z = x+y

# %%
ax = plt.axes(projection='3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_xlabel('y')
ax.set_xlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax = plt.axes(projection='3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_xlabel('sepal_width')
ax.set_xlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.plot(kind='hist',figsize=(20,10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.sepal_length.plot(kind='hist',figsize=(20,10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist(figsize=(20,10),color='g',alpha=0.9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='#120E43',alpha=0.9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="6609c4ed-9f2c-4724-bc4a-b1f9c83478d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width',kind='scatter',mode='markers')
# Out:
# <div>                            <div id="809fbf5d-ca7f-44bb-b6b7-c3d6371a22b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width',size='sepal_length',kind='bubble')
# Out:
# <div>                            <div id="e3450a9d-3747-4ff6-af92-baaf8fbb7094" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='sepal_width',z='petal_length',size='sepal_length',kind='bubble3d')
# Out:
# <div>                            <div id="d49fba44-de36-421c-9a76-0cd20732f00c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.iplot(x='total_bill',y='tip',kind='scatter',mode='markers')
# Out:
# <div>                            <div id="6b5a2180-b6a5-4929-bb8a-6895e1bde8b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x='total_bill',y='tip',data=df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='sex')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='sex',col='time')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,col='species')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='sex',col='day')

# %%
sns.catplot(x='day',y='total_bill',data=df1)

# %%
sns.pairplot(df1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="2a346ff9-68e6-4474-b4c7-5b761a76d6c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip)

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip,kind='hex')

# %%
sns.regplot(x=df1['total_bill'],y=df1['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
